# %% [markdown]
# # Linear Regression Analysis: Housing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from pandas.plotting import scatter_matrix
import statsmodels.formula.api as smf #for regression analysis

# %%
housing = pd.read_csv('C:\\Users\\Computer Care\\Downloads\\Files\\housing.csv', index_col = 0)

# %%
housing.head()
# Out:
#    LSTAT  INDUS    NOX     RM  MEDV
# 0   4.98   2.31  0.538  6.575  24.0
# 1   9.14   7.07  0.469  6.421  21.6
# 2   4.03   7.07  0.469  7.185  34.7
# 3   2.94   2.18  0.458  6.998  33.4
# 4   5.33   2.18  0.458  7.147  36.2

# %% [markdown]
# ##### Dictionary:
# * LSTAT = 'Low Status' Population,
# * INDUS = Proportin o non-retail business acres per town,
# * NOX = Nitric Oxides Concetration,
# * RM = Average Number of Rooms,
# * MEDV = Median value of homes

# %% [markdown]
# #### 1. Covariance

# %%
#To check association 
housing.cov()
# Out:
#            LSTAT      INDUS       NOX        RM       MEDV
# LSTAT  50.994760  29.580270  0.488946 -3.079741 -48.447538
# INDUS  29.580270  47.064442  0.607074 -1.887957 -30.520823
# NOX     0.488946   0.607074  0.013428 -0.024603  -0.455412
# RM     -3.079741  -1.887957 -0.024603  0.493671   4.493446
# MEDV  -48.447538 -30.520823 -0.455412  4.493446  84.586724

# %% [markdown]
# By values we can not tell which has strong association, correlation is more appropriate to calculate the associationin this case

# %% [markdown]
# #### 2. Coefficient of Correlation

# %%
housing.corr()
#Diagonal elemets are one, itslef perfectly correlated
# Out:
#           LSTAT     INDUS       NOX        RM      MEDV
# LSTAT  1.000000  0.603800  0.590879 -0.613808 -0.737663
# INDUS  0.603800  1.000000  0.763651 -0.391676 -0.483725
# NOX    0.590879  0.763651  1.000000 -0.302188 -0.427321
# RM    -0.613808 -0.391676 -0.302188  1.000000  0.695360
# MEDV  -0.737663 -0.483725 -0.427321  0.695360  1.000000

# %% [markdown]
# #### 3. Scatter Matrix

# %%
scatter_matrix(housing, figsize = (15,15))
plt.show()
# The histogram are diagonal are those of variable
# RM has strong linear pattern with MEDV, 
# LSTAT as non-linear pattern with MEDV
plt.savefig('SLR.png',bbox_inches = 'tight',pad_inches=1)

# %%
housing.plot(kind = 'scatter',x = 'RM', y = 'MEDV', figsize = (10,8))                         # strong assosiation
plt.show()

# %% [markdown]
# # Simple linear Regression

# %% [markdown]
#  $y_i = \beta_0 + \beta_1 * x_i + \epsilon_i$
#    (ObserverError)

# %% [markdown]
# Association between RM and MEDV to make simple linear regression model to estimate the value of $B_0$ (intercept) and $B_1$ (slop)

# %%
# Prediction equation is to guess the real value of intercept and slop 
# we use b0, b1 to get a straght line that describe our data and predict values of response 

b0 = 0.1
b1 = 1
housing['GuessResponse'] = b0 + b1 * housing.RM                                                 #regression equation

# To check the error of guess. This shows how far is the guess response from true response
housing['ObservedError'] = housing.MEDV - housing.GuessResponse 

#To check observed error for 7's, 20's, and 100's pairs from the samples.
indices = [7 , 20, 100]
print(housing.ObservedError.loc[indices])
SSE  = (housing['ObservedError']**2).sum()
print('Sum of square Error is', SSE)
# Out:
# 7      20.828
# 20      7.930
# 100    20.673
# Name: ObservedError, dtype: float64
# Sum of square Error is 170373.528047

# %%
# Plot estimate line together with the points
plt.figure(figsize  = (8,8))
plt.title('SSE is {}'.format(SSE))

plt.scatter(housing.RM, housing.MEDV, color='g', label='Observed')
plt.plot(housing.RM, housing.GuessResponse, color = 'r', label = 'GuessResponse') #Regression line

plt.xlim(housing.RM.min()-2, housing.RM.max()+2)
plt.ylim(housing.MEDV.min()-2, housing.MEDV.max()+2)
plt.legend()
plt.show()

# %% [markdown]
# # OLS (Ordinary least  Square estimation)

# %%
# OLS to minimize SSE and check best fit line
model = smf.ols(formula = 'MEDV ~ RM', data = housing).fit()                       #regression model
                     
# for estimated slope and intercept we use ols
b0_ols = model.params.iloc[0] 
b1_ols = model.params.iloc[1]

housing['BestResponse'] = b0_ols + b1_ols * housing.RM
housing['Error'] = housing.MEDV - housing.BestResponse
# error after ols
SSE2  = (housing['Error']**2).sum()
print('Sum of square Error is', SSE2)
# Out:
# Sum of square Error is 22061.879196211798

# %%
# Plot estimate line together with the points, Regression line and best fit line
plt.figure(figsize  = (10,8))
plt.title('SSE is {}'.format(SSE2))

plt.scatter(housing.RM, housing.MEDV, color='g', label='Observed')
plt.plot(housing.RM, housing.GuessResponse, color = 'r', label = 'Regression')                #Regression line
plt.plot(housing.RM, housing.BestResponse, color= 'blue' , label = 'BestFit')                 #best fit SSE2 smaller

plt.xlim(housing.RM.min()-2, housing.RM.max()+2)
plt.ylim(housing.MEDV.min()-2, housing.MEDV.max()+2)
plt.legend()
plt.show()

# %% [markdown]
# # Diagonstic of Linear regression

# %% [markdown]
# Assumption behind linear regression model
# 1. Assosiation/linearity between RM and MEDV (a closer look)
# 2. Independence
# 3. Normality
# 4. Equal Variance

# %%
model = smf.ols(formula='MEDV~LSTAT', data=housing).fit()
 
b0_ols = model.params.iloc[0]
b1_ols = model.params.iloc[1]

housing['BestResponse'] = b0_ols + b1_ols*housing['LSTAT']

# %% [markdown]
# # Linearity

# %%
housing.plot(kind = 'scatter',x = 'MEDV', y = 'LSTAT', figsize = (10,10))
plt.show()
# scatter plot has it is non-linear pattern
#  assuumption violated

# %% [markdown]
# # Independence

# %%
# Observed Error is independent, no correlation in errors
housing['Error'] = housing.MEDV - housing.BestResponse
# Method 1, Error vs order fast check
plt.figure(figsize = (15,8))
plt.title('Residual vs Order')
plt.plot(housing.index, housing.Error, color = 'purple')
plt.axhline(y = 0, color = 'r')
plt.show()
# no obvios pattern in the plot

# %%
# Method 2, Durbin Watson Test refers to p-value of y(LSTAT), CI and R-square to evaluate conclusion
model.summary()
# rule of thumb that test statistics value is in range -1.026 to -0.874 are normal
# below -1.026 eror positive corelated and above - 0.874 error negative corellated
# asssumption violated DW is 0.892
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     601.6
# Date:                Wed, 15 May 2024   Prob (F-statistic):           5.08e-88
# Time:                        09:02:58   Log-Likelihood:                -1641.5
# No. Observations:                 506   AIC:                             3287.
# Df Residuals:                     504   BIC:                             3295.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     34.5538      0.563     61.415      0.000      33.448      35.659
# ...

# %% [markdown]
# ##### P-value of slop
# p-value of slop(LSTAT) check, this is two tail test follows t-dist with dof n-2->cause it loss 2 var freedom
# p = 0.000 < 0.05, reject null means y =! 0, predict LSTAT is useful in predict the mean value of housing
# not reject means the chosen var y is good to predict the x, hypothesis
# we have only 5% chance that the predict var could be wrong, alpha = 0.05
# ##### CI of slop
# Confidence Interval is 95% which means 5% chance the model can be incorrect
# 95% is between -1.026 and -0.0874, range located on the negative side of real line and the slop is negative with high chance which is consistet with corelation of scatter plot of or data
# ##### R-square
# importat measre of performanvce of model
# compte variation of y without model which is sum of deviatiion-> sum(y-ybar)^2 =SST --> total variation
# if large diff btw prediction and  mean y is large, SSR of predict y -> sum(yhat-ybar)^2 --> variation explained
# prediction is diff from mean response which is estimatedd value of response withot model
# OLS,if variation of response can not be exploaninec by model ir predictorSSE --> variation unexpLained
# SST = SSR + SSE, SSE relatively smaller
# simple linear regression, R-square = 1 - SSE/SST
# in model MEDV is 0.544, 54.4% off variation explained by or model
# ##### two facts for R high or low
# if Rsquare < 50%, variable not uniquely determine by model and there is big portion of it not explined by other varibales for which we need multiple regreesion
# R-square < 50% is high enouugh, for noisy data

# %% [markdown]
# # Normality

# %%
#  normal distribution
import scipy.stats as stats
z = (housing.Error - housing.Error.mean())/housing.Error.std(ddof=1) #standardize error
stats.probplot(z, dist = 'norm', plot = plt) #for QQ plot

plt.title('Normal Q-Q plot')
plt.show()
# to follow norm dist line fall 45degree roughly, here line is a bit on right tail but 
# assumption satisfied normality

# %% [markdown]
# # Equal Variance

# %%
#  observed error/ residual vs predictor
housing.plot(kind = 'scatter', x = 'LSTAT', y = 'Error', color = 'g', figsize  = (10,8))
plt.title('Residual vs Predictor')
plt.axhline(y = 0, color = 'r')
plt.show()
# if variance of noise is diff for diff var predictor it not hv pattern.
# here noise var is smaller or big no of houses
# var is small for large lstat
# assumpotion violated

# %% [markdown]
# 1. assumption violated model not found on inference
# 2. accurancy and consistency not based on there asssumptions
# 3. model can not be predicted by this variable

# %% [markdown]
# ## We can see that the regression model (MEDV~LSTAT) violates all four assumptions. Therefore, we cannot make statistical inference using this model.
